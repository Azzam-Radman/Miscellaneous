# %% [markdown]
# # LeaveOneFeatureOut (LOFO):
# * This is one of the most powerful and guaranteed techniques for feature selection. It iteratively drops out one feature at a time and tests the performance of your selected model on your selected folds. If the dropout of the feature improves the CV score, then the training set gets updated and continues the iterations for furthur improvement. <br>
# * This notebook contains an easy-to-use code for the purpose of this competition, however, it can be used for any other tabular dataset and for any task with just little modifications. <br>
# * All you need is to pass your training set (X), label (y), model, n_splits (for KFold cross validation), and evaluation metric.
# * Because this might take a significant amount of time in the case of 100 features, this code will be run of the first 10 features only.
# * Moreover, you can use a simpler model to speedup the process of FS.

# %%
import pandas as pd
import numpy as np
from sklearn import model_selection, metrics
from catboost import CatBoostRegressor

# %%
train = pd.read_csv('../input/tabular-playground-series-aug-2021/train.csv')
X = train.drop('loss', axis=1).iloc[:, :10] # only the ten first features will be used for the purpose of demonstration
y = train.loss
test = pd.read_csv('../input/tabular-playground-series-aug-2021/test.csv').iloc[:, :10]

# %%
# just run this cell

class LOFO(object):
    
    def __init__(self, data, labels, model, n_splits, eval_metric):
        self._data = data
        self._labels = labels
        self.model = model
        self.n_splits = n_splits
        self.eval_metric = eval_metric
        
        
    def kfold(self, x, y, model, n_splits, eval_metric):
        from sklearn import model_selection
        
        preds_valid_array = np.zeros(y.shape[0])
        
        train_scores = []
        valid_scores = []
        
        kf = model_selection.KFold(n_splits=n_splits)
        for fold, (train_idx, valid_idx) in enumerate(kf.split(x)):
            
            print(f"===================== Fold {fold+1} =====================")
            x_train, y_train = x[train_idx, :], y[train_idx]
            x_valid, y_valid = x[valid_idx, :], y[valid_idx]
            
            self.model.fit(
                          x_train, y_train,
                          eval_set=[(x_valid, y_valid)],
                          verbose=100
                         )
            
            preds_valid = model.predict(x_valid)
            preds_train = model.predict(x_train)
            
            valid_score = np.sqrt(eval_metric(y_valid, preds_valid))
            train_score = np.sqrt(eval_metric(y_train, preds_train))
            
            valid_scores.append(valid_score)
            train_scores.append(train_score)
            
            preds_valid_array[valid_idx] += preds_valid
            
        print("Mean valid score =", np.mean(valid_scores), "STD valid score = ", np.std(valid_scores, ddof=1))
        print("Mean train score =", np.mean(train_scores), "STD train score = ", np.std(train_scores, ddof=1))
        
        cv_score = np.mean(valid_scores)
        return cv_score, preds_valid_array
    
    def selectionLoop(self, x, y, model, n_splits, eval_metric):
        
        print("All Features")
        cv_score, preds_valid = self.kfold(x, y, model, n_splits, eval_metric)
        score = cv_score
        scores = []
        good_scores = []
        scores.append(score)
        good_scores.append(score)
        harmful_features = []
        print("=================================================")
        
        
        for i in range(x.shape[1]):
            
            print(f"Drop Feature {i}")
            x2 = pd.DataFrame(x, columns=[f"col_{i}" for i in range(x.shape[1])])
            x2 = x2.drop(x2.columns[i], axis=1)
            x2 = x2.dropna(axis=1, how='all').values
            cv_score, preds_valid = self.kfold(x2, y, model, n_splits, eval_metric)  
            if cv_score < score:
                score = cv_score
                print("Improved Score =", score)
                good_scores.append(score)
                harmful_features.append(i)
                x = pd.DataFrame(x, columns=[f"col_{i}" for i in range(x.shape[1])])
                x.iloc[:, i] = np.nan
                x = x.values
                print("=================================================")
                
            else:
                continue
        
        print("Good scores :", good_scores)
        print("Harmful features :", harmful_features)
        
        return good_scores, harmful_features
    
    def transform(self, X, test):
        
        X = self._data
        y = self._labels
        model = self.model
        n_splits = self.n_splits
        eval_metric = self.eval_metric
        
        good_scores, harmful_features = self.selectionLoop(X.values, y.values, model, n_splits, eval_metric)
        X = X.drop(list(X.columns.tolist()[i] for i in harmful_features), axis=1)
        X = X.dropna(axis=1, how='all')
        test = test.drop(list(test.columns.tolist()[i] for i in harmful_features), axis=1)
        
        return X, test

# %%
# pass your arguments here
# X, y and test should be in the form of Pandas DataFrames    
lofo = LOFO(X, y, model=CatBoostRegressor(
                                   learning_rate=0.03,
                                   iterations=10000,
                                   loss_function='RMSE',
                                   eval_metric='RMSE',
                                   use_best_model=True,
                                   early_stopping_rounds=100
                                   ), n_splits=5, eval_metric=metrics.mean_squared_error)

X, test = LOFO.transform(lofo, X, test)
# Out:
# All Features
# ===================== Fold 1 =====================
# 0:	learn: 7.9469448	test: 7.9113945	best: 7.9113945 (0)	total: 77.5ms	remaining: 12m 54s
# 100:	learn: 7.9313693	test: 7.9046870	best: 7.9045045 (97)	total: 1.88s	remaining: 3m 3s
# 200:	learn: 7.9225553	test: 7.9044847	best: 7.9044847 (200)	total: 3.65s	remaining: 2m 57s
# 300:	learn: 7.9147798	test: 7.9044668	best: 7.9041505 (263)	total: 5.42s	remaining: 2m 54s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.904150506
# bestIteration = 263
#
# Shrink model to first 264 iterations.
# ===================== Fold 2 =====================
# 0:	learn: 7.9517648	test: 7.8921421	best: 7.8921421 (0)	total: 19.1ms	remaining: 3m 11s
# 100:	learn: 7.9367418	test: 7.8847378	best: 7.8847378 (100)	total: 1.83s	remaining: 2m 59s
# 200:	learn: 7.9278091	test: 7.8835805	best: 7.8834885 (163)	total: 3.62s	remaining: 2m 56s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.883488528
# bestIteration = 163
#
# Shrink model to first 164 iterations.
# ===================== Fold 3 =====================
# 0:	learn: 7.9329327	test: 7.9677178	best: 7.9677178 (0)	total: 19.6ms	remaining: 3m 15s
# 100:	learn: 7.9181665	test: 7.9596628	best: 7.9596628 (100)	total: 1.82s	remaining: 2m 58s
# 200:	learn: 7.9098120	test: 7.9584578	best: 7.9584578 (200)	total: 3.69s	remaining: 3m
# 300:	learn: 7.9020287	test: 7.9582628	best: 7.9581838 (266)	total: 5.55s	remaining: 2m 58s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.958183831
# bestIteration = 266
#
# Shrink model to first 267 iterations.
# ===================== Fold 4 =====================
# 0:	learn: 7.9322909	test: 7.9700950	best: 7.9700950 (0)	total: 18ms	remaining: 3m
# 100:	learn: 7.9173265	test: 7.9628509	best: 7.9628509 (100)	total: 1.81s	remaining: 2m 57s
# 200:	learn: 7.9081051	test: 7.9622643	best: 7.9622200 (183)	total: 3.65s	remaining: 2m 57s
# 300:	learn: 7.9002658	test: 7.9619102	best: 7.9618806 (297)	total: 5.45s	remaining: 2m 55s
# 400:	learn: 7.8922603	test: 7.9619625	best: 7.9618689 (389)	total: 7.22s	remaining: 2m 52s
# 500:	learn: 7.8839755	test: 7.9620628	best: 7.9618655 (435)	total: 8.94s	remaining: 2m 49s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.961865475
# bestIteration = 435
#
# Shrink model to first 436 iterations.
# ===================== Fold 5 =====================
# 0:	learn: 7.9353084	test: 7.9580970	best: 7.9580970 (0)	total: 18.2ms	remaining: 3m 1s
# 100:	learn: 7.9202896	test: 7.9497050	best: 7.9497050 (100)	total: 1.82s	remaining: 2m 58s
# 200:	learn: 7.9115846	test: 7.9489385	best: 7.9487133 (182)	total: 3.63s	remaining: 2m 56s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.948713325
# bestIteration = 182
#
# Shrink model to first 183 iterations.
# Mean valid score = 7.931280332811913 STD valid score =  0.035296042475098884
# Mean train score = 7.911168895995409 STD train score =  0.015419960939207864
# =================================================
# Drop Feature 0
# ===================== Fold 1 =====================
# 0:	learn: 7.9469440	test: 7.9113782	best: 7.9113782 (0)	total: 17.6ms	remaining: 2m 56s
# 100:	learn: 7.9318636	test: 7.9044182	best: 7.9044182 (100)	total: 1.82s	remaining: 2m 58s
# 200:	learn: 7.9236259	test: 7.9036134	best: 7.9035180 (170)	total: 3.62s	remaining: 2m 56s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.903517993
# bestIteration = 170
#
# Shrink model to first 171 iterations.
# ===================== Fold 2 =====================
# 0:	learn: 7.9517427	test: 7.8921285	best: 7.8921285 (0)	total: 17.4ms	remaining: 2m 54s
# 100:	learn: 7.9364910	test: 7.8846646	best: 7.8846337 (96)	total: 1.81s	remaining: 2m 57s
# 200:	learn: 7.9281776	test: 7.8836185	best: 7.8836185 (200)	total: 3.58s	remaining: 2m 54s
# 300:	learn: 7.9206292	test: 7.8834335	best: 7.8833874 (288)	total: 5.38s	remaining: 2m 53s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.883387362
# bestIteration = 288
#
# Shrink model to first 289 iterations.
# ===================== Fold 3 =====================
# 0:	learn: 7.9328747	test: 7.9676499	best: 7.9676499 (0)	total: 18.7ms	remaining: 3m 6s
# 100:	learn: 7.9181718	test: 7.9595209	best: 7.9595209 (100)	total: 1.84s	remaining: 3m
# 200:	learn: 7.9101578	test: 7.9582907	best: 7.9582493 (194)	total: 3.63s	remaining: 2m 57s
# 300:	learn: 7.9030066	test: 7.9576754	best: 7.9576173 (288)	total: 5.43s	remaining: 2m 54s
# 400:	learn: 7.8956352	test: 7.9578635	best: 7.9575414 (339)	total: 7.24s	remaining: 2m 53s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.957541374
# bestIteration = 339
#
# Shrink model to first 340 iterations.
# ===================== Fold 4 =====================
# 0:	learn: 7.9322393	test: 7.9700831	best: 7.9700831 (0)	total: 17.1ms	remaining: 2m 51s
# 100:	learn: 7.9170425	test: 7.9631063	best: 7.9631063 (100)	total: 2.01s	remaining: 3m 17s
# 200:	learn: 7.9085737	test: 7.9620611	best: 7.9620539 (196)	total: 3.88s	remaining: 3m 9s
# 300:	learn: 7.9011567	test: 7.9620250	best: 7.9619484 (235)	total: 5.68s	remaining: 3m 3s
# 400:	learn: 7.8941763	test: 7.9618102	best: 7.9617512 (341)	total: 7.45s	remaining: 2m 58s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.961751161
# bestIteration = 341
#
# Shrink model to first 342 iterations.
# ===================== Fold 5 =====================
# 0:	learn: 7.9352590	test: 7.9580641	best: 7.9580641 (0)	total: 17ms	remaining: 2m 50s
# 100:	learn: 7.9204044	test: 7.9501235	best: 7.9501235 (100)	total: 1.79s	remaining: 2m 55s
# 200:	learn: 7.9117571	test: 7.9491682	best: 7.9491037 (192)	total: 3.59s	remaining: 2m 54s
# 300:	learn: 7.9043672	test: 7.9492547	best: 7.9490736 (264)	total: 5.35s	remaining: 2m 52s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.949073564
# bestIteration = 264
#
# Shrink model to first 265 iterations.
# Mean valid score = 7.931054290827151 STD valid score =  0.035351596331975925
# Mean train score = 7.9105498627192095 STD train score =  0.012535286127881861
# Improved Score = 7.931054290827151
# =================================================
# Drop Feature 1
# ===================== Fold 1 =====================
# 0:	learn: 7.9469417	test: 7.9113638	best: 7.9113638 (0)	total: 17.2ms	remaining: 2m 51s
# 100:	learn: 7.9322221	test: 7.9039859	best: 7.9039859 (100)	total: 1.65s	remaining: 2m 41s
# 200:	learn: 7.9241775	test: 7.9032046	best: 7.9032046 (200)	total: 3.23s	remaining: 2m 37s
# 300:	learn: 7.9171227	test: 7.9027864	best: 7.9027407 (297)	total: 4.79s	remaining: 2m 34s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.902740739
# bestIteration = 297
#
# Shrink model to first 298 iterations.
# ===================== Fold 2 =====================
# 0:	learn: 7.9517113	test: 7.8921423	best: 7.8921423 (0)	total: 15.8ms	remaining: 2m 37s
# 100:	learn: 7.9374034	test: 7.8846190	best: 7.8846158 (98)	total: 1.64s	remaining: 2m 41s
# 200:	learn: 7.9294344	test: 7.8835131	best: 7.8834753 (198)	total: 3.28s	remaining: 2m 40s
# 300:	learn: 7.9221880	test: 7.8834637	best: 7.8833334 (234)	total: 4.87s	remaining: 2m 36s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.883333385
# bestIteration = 234
#
# Shrink model to first 235 iterations.
# ===================== Fold 3 =====================
# 0:	learn: 7.9328542	test: 7.9676095	best: 7.9676095 (0)	total: 15.6ms	remaining: 2m 35s
# 100:	learn: 7.9186203	test: 7.9593912	best: 7.9593912 (100)	total: 1.62s	remaining: 2m 39s
# 200:	learn: 7.9110477	test: 7.9579068	best: 7.9578760 (197)	total: 3.23s	remaining: 2m 37s
# 300:	learn: 7.9041602	test: 7.9578389	best: 7.9576898 (272)	total: 4.82s	remaining: 2m 35s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.957689778
# bestIteration = 272
#
# Shrink model to first 273 iterations.
# ===================== Fold 4 =====================
# 0:	learn: 7.9322708	test: 7.9701682	best: 7.9701682 (0)	total: 15.8ms	remaining: 2m 38s
# 100:	learn: 7.9171431	test: 7.9628620	best: 7.9628620 (100)	total: 1.6s	remaining: 2m 37s
# 200:	learn: 7.9092870	test: 7.9620986	best: 7.9620697 (197)	total: 3.19s	remaining: 2m 35s
# 300:	learn: 7.9021173	test: 7.9617352	best: 7.9617168 (263)	total: 4.77s	remaining: 2m 33s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.961716843
# bestIteration = 263
#
# Shrink model to first 264 iterations.
# ===================== Fold 5 =====================
# 0:	learn: 7.9353436	test: 7.9580819	best: 7.9580819 (0)	total: 17.4ms	remaining: 2m 53s
# 100:	learn: 7.9205976	test: 7.9501015	best: 7.9501015 (100)	total: 1.6s	remaining: 2m 37s
# 200:	learn: 7.9130373	test: 7.9492344	best: 7.9492200 (199)	total: 3.19s	remaining: 2m 35s
# 300:	learn: 7.9058749	test: 7.9491225	best: 7.9491207 (297)	total: 4.77s	remaining: 2m 33s
# 400:	learn: 7.8991423	test: 7.9494909	best: 7.9491010 (307)	total: 6.33s	remaining: 2m 31s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.949100972
# bestIteration = 307
#
# Shrink model to first 308 iterations.
# Mean valid score = 7.930916343242673 STD valid score =  0.035546346222122154
# Mean train score = 7.912065542193763 STD train score =  0.00978069587144716
# Improved Score = 7.930916343242673
# =================================================
# Drop Feature 2
# ===================== Fold 1 =====================
# 0:	learn: 7.9469460	test: 7.9113722	best: 7.9113722 (0)	total: 16.6ms	remaining: 2m 45s
# 100:	learn: 7.9340086	test: 7.9051100	best: 7.9051100 (100)	total: 1.68s	remaining: 2m 44s
# 200:	learn: 7.9268628	test: 7.9044724	best: 7.9044724 (200)	total: 3.55s	remaining: 2m 53s
# 300:	learn: 7.9206536	test: 7.9041609	best: 7.9040443 (292)	total: 5.49s	remaining: 2m 56s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.904044336
# bestIteration = 292
#
# Shrink model to first 293 iterations.
# ===================== Fold 2 =====================
# 0:	learn: 7.9517764	test: 7.8920735	best: 7.8920735 (0)	total: 16.5ms	remaining: 2m 44s
# 100:	learn: 7.9385715	test: 7.8856662	best: 7.8856662 (100)	total: 1.72s	remaining: 2m 48s
# 200:	learn: 7.9311752	test: 7.8845686	best: 7.8845443 (197)	total: 3.43s	remaining: 2m 47s
# 300:	learn: 7.9248712	test: 7.8845466	best: 7.8844102 (225)	total: 5.1s	remaining: 2m 44s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.884410159
# bestIteration = 225
#
# Shrink model to first 226 iterations.
# ===================== Fold 3 =====================
# 0:	learn: 7.9328732	test: 7.9675747	best: 7.9675747 (0)	total: 15.6ms	remaining: 2m 36s
# 100:	learn: 7.9201459	test: 7.9612544	best: 7.9612544 (100)	total: 1.69s	remaining: 2m 45s
# 200:	learn: 7.9129490	test: 7.9604450	best: 7.9603616 (189)	total: 3.36s	remaining: 2m 43s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.960361594
# bestIteration = 189
#
# Shrink model to first 190 iterations.
# ===================== Fold 4 =====================
# 0:	learn: 7.9322329	test: 7.9700954	best: 7.9700954 (0)	total: 16.6ms	remaining: 2m 45s
# 100:	learn: 7.9188056	test: 7.9645149	best: 7.9645149 (100)	total: 1.72s	remaining: 2m 48s
# 200:	learn: 7.9115123	test: 7.9640526	best: 7.9640327 (190)	total: 3.36s	remaining: 2m 43s
# 300:	learn: 7.9048210	test: 7.9642141	best: 7.9639235 (220)	total: 5.02s	remaining: 2m 41s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.9639235
# bestIteration = 220
#
# Shrink model to first 221 iterations.
# ===================== Fold 5 =====================
# 0:	learn: 7.9352807	test: 7.9580888	best: 7.9580888 (0)	total: 16.7ms	remaining: 2m 47s
# 100:	learn: 7.9220698	test: 7.9516600	best: 7.9516507 (98)	total: 1.7s	remaining: 2m 46s
# 200:	learn: 7.9149524	test: 7.9511223	best: 7.9510080 (177)	total: 3.57s	remaining: 2m 54s
# 300:	learn: 7.9086133	test: 7.9510264	best: 7.9509523 (233)	total: 5.47s	remaining: 2m 56s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.950952292
# bestIteration = 233
#
# Shrink model to first 234 iterations.
# Mean valid score = 7.932738375942566 STD valid score =  0.03614645683451308
# Mean train score = 7.91749267255004 STD train score =  0.007917564339533171
# Drop Feature 3
# ===================== Fold 1 =====================
# 0:	learn: 7.9469612	test: 7.9114428	best: 7.9114428 (0)	total: 16.5ms	remaining: 2m 45s
# 100:	learn: 7.9338745	test: 7.9064500	best: 7.9064056 (95)	total: 1.69s	remaining: 2m 45s
# 200:	learn: 7.9269506	test: 7.9063382	best: 7.9061976 (143)	total: 3.31s	remaining: 2m 41s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.906197557
# bestIteration = 143
#
# Shrink model to first 144 iterations.
# ===================== Fold 2 =====================
# 0:	learn: 7.9517682	test: 7.8920712	best: 7.8920712 (0)	total: 16.2ms	remaining: 2m 41s
# 100:	learn: 7.9385780	test: 7.8859075	best: 7.8859075 (100)	total: 1.67s	remaining: 2m 43s
# 200:	learn: 7.9311201	test: 7.8853459	best: 7.8852852 (140)	total: 3.3s	remaining: 2m 40s
# 300:	learn: 7.9246315	test: 7.8853837	best: 7.8852118 (221)	total: 4.97s	remaining: 2m 40s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.885211827
# bestIteration = 221
#
# Shrink model to first 222 iterations.
# ===================== Fold 3 =====================
# 0:	learn: 7.9328806	test: 7.9675916	best: 7.9675916 (0)	total: 15.7ms	remaining: 2m 37s
# 100:	learn: 7.9202625	test: 7.9606436	best: 7.9606436 (100)	total: 1.67s	remaining: 2m 43s
# 200:	learn: 7.9132897	test: 7.9598228	best: 7.9597997 (189)	total: 3.38s	remaining: 2m 44s
# 300:	learn: 7.9070267	test: 7.9593052	best: 7.9593052 (300)	total: 5.06s	remaining: 2m 42s
# 400:	learn: 7.9006714	test: 7.9590268	best: 7.9590268 (400)	total: 6.7s	remaining: 2m 40s
# 500:	learn: 7.8935471	test: 7.9587641	best: 7.9587106 (495)	total: 8.34s	remaining: 2m 38s
# 600:	learn: 7.8861210	test: 7.9588676	best: 7.9586220 (557)	total: 9.98s	remaining: 2m 36s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.95862205
# bestIteration = 557
#
# Shrink model to first 558 iterations.
# ===================== Fold 4 =====================
# 0:	learn: 7.9323319	test: 7.9701394	best: 7.9701394 (0)	total: 16.9ms	remaining: 2m 48s
# 100:	learn: 7.9189167	test: 7.9647082	best: 7.9647082 (100)	total: 2.07s	remaining: 3m 23s
# 200:	learn: 7.9118846	test: 7.9643335	best: 7.9641910 (147)	total: 3.71s	remaining: 3m
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.964190954
# bestIteration = 147
#
# Shrink model to first 148 iterations.
# ===================== Fold 5 =====================
# 0:	learn: 7.9353026	test: 7.9581217	best: 7.9581217 (0)	total: 20.8ms	remaining: 3m 28s
# 100:	learn: 7.9221890	test: 7.9522405	best: 7.9521892 (95)	total: 1.7s	remaining: 2m 46s
# 200:	learn: 7.9150821	test: 7.9520362	best: 7.9518460 (173)	total: 3.38s	remaining: 2m 44s
# 300:	learn: 7.9086946	test: 7.9521615	best: 7.9518359 (238)	total: 5.06s	remaining: 2m 43s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.951835942
# bestIteration = 238
#
# Shrink model to first 239 iterations.
# Mean valid score = 7.933211665746365 STD valid score =  0.0353058569400825
# Mean train score = 7.9156051821224 STD train score =  0.016793677895017164
# Drop Feature 4
# ===================== Fold 1 =====================
# 0:	learn: 7.9469980	test: 7.9114484	best: 7.9114484 (0)	total: 16.7ms	remaining: 2m 47s
# 100:	learn: 7.9342936	test: 7.9055791	best: 7.9055791 (100)	total: 1.68s	remaining: 2m 44s
# 200:	learn: 7.9274498	test: 7.9048903	best: 7.9048903 (200)	total: 3.32s	remaining: 2m 41s
# 300:	learn: 7.9211809	test: 7.9050249	best: 7.9048395 (202)	total: 4.97s	remaining: 2m 40s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.904839528
# bestIteration = 202
#
# Shrink model to first 203 iterations.
# ===================== Fold 2 =====================
# 0:	learn: 7.9517453	test: 7.8920448	best: 7.8920448 (0)	total: 15.7ms	remaining: 2m 36s
# 100:	learn: 7.9390559	test: 7.8862527	best: 7.8862527 (100)	total: 1.73s	remaining: 2m 49s
# 200:	learn: 7.9316946	test: 7.8854354	best: 7.8853669 (198)	total: 3.39s	remaining: 2m 45s
# 300:	learn: 7.9250605	test: 7.8853651	best: 7.8852959 (262)	total: 5.03s	remaining: 2m 41s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.885295903
# bestIteration = 262
#
# Shrink model to first 263 iterations.
# ===================== Fold 3 =====================
# 0:	learn: 7.9329110	test: 7.9676323	best: 7.9676323 (0)	total: 15.6ms	remaining: 2m 35s
# 100:	learn: 7.9207664	test: 7.9611185	best: 7.9611185 (100)	total: 1.64s	remaining: 2m 41s
# 200:	learn: 7.9138982	test: 7.9598849	best: 7.9598849 (200)	total: 3.35s	remaining: 2m 43s
# 300:	learn: 7.9076600	test: 7.9597048	best: 7.9595235 (283)	total: 5.38s	remaining: 2m 53s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.959523535
# bestIteration = 283
#
# Shrink model to first 284 iterations.
# ===================== Fold 4 =====================
# 0:	learn: 7.9322942	test: 7.9701574	best: 7.9701574 (0)	total: 16.5ms	remaining: 2m 44s
# 100:	learn: 7.9195434	test: 7.9644737	best: 7.9644728 (98)	total: 1.69s	remaining: 2m 45s
# 200:	learn: 7.9125796	test: 7.9637995	best: 7.9637739 (187)	total: 3.32s	remaining: 2m 42s
# 300:	learn: 7.9065666	test: 7.9639897	best: 7.9637117 (220)	total: 4.98s	remaining: 2m 40s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.963711655
# bestIteration = 220
#
# Shrink model to first 221 iterations.
# ===================== Fold 5 =====================
# 0:	learn: 7.9352789	test: 7.9581709	best: 7.9581709 (0)	total: 16ms	remaining: 2m 39s
# 100:	learn: 7.9222981	test: 7.9525244	best: 7.9525242 (99)	total: 1.68s	remaining: 2m 44s
# 200:	learn: 7.9152030	test: 7.9516769	best: 7.9515367 (180)	total: 3.31s	remaining: 2m 41s
# 300:	learn: 7.9089018	test: 7.9518293	best: 7.9515054 (263)	total: 4.92s	remaining: 2m 38s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.95150538
# bestIteration = 263
#
# Shrink model to first 264 iterations.
# Mean valid score = 7.93297520013257 STD valid score =  0.0355592559654552
# Mean train score = 7.917305288031633 STD train score =  0.009340917555089555
# Drop Feature 5
# ===================== Fold 1 =====================
# 0:	learn: 7.9469668	test: 7.9114306	best: 7.9114306 (0)	total: 17.3ms	remaining: 2m 53s
# 100:	learn: 7.9324797	test: 7.9044910	best: 7.9044910 (100)	total: 1.71s	remaining: 2m 47s
# 200:	learn: 7.9253836	test: 7.9035458	best: 7.9035458 (200)	total: 3.37s	remaining: 2m 44s
# 300:	learn: 7.9190439	test: 7.9036288	best: 7.9034654 (264)	total: 5s	remaining: 2m 41s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.903465412
# bestIteration = 264
#
# Shrink model to first 265 iterations.
# ===================== Fold 2 =====================
# 0:	learn: 7.9517453	test: 7.8920218	best: 7.8920218 (0)	total: 15.8ms	remaining: 2m 37s
# 100:	learn: 7.9373335	test: 7.8849752	best: 7.8849752 (100)	total: 1.65s	remaining: 2m 41s
# 200:	learn: 7.9299422	test: 7.8841784	best: 7.8841120 (177)	total: 3.45s	remaining: 2m 48s
# 300:	learn: 7.9234530	test: 7.8843797	best: 7.8840364 (233)	total: 5.34s	remaining: 2m 52s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.884036435
# bestIteration = 233
#
# Shrink model to first 234 iterations.
# ===================== Fold 3 =====================
# 0:	learn: 7.9328993	test: 7.9676256	best: 7.9676256 (0)	total: 16.7ms	remaining: 2m 47s
# 100:	learn: 7.9190177	test: 7.9595478	best: 7.9595478 (100)	total: 1.68s	remaining: 2m 44s
# 200:	learn: 7.9118394	test: 7.9580680	best: 7.9580680 (200)	total: 3.34s	remaining: 2m 42s
# 300:	learn: 7.9055537	test: 7.9578823	best: 7.9578050 (267)	total: 4.97s	remaining: 2m 40s
# 400:	learn: 7.8992684	test: 7.9577089	best: 7.9577074 (399)	total: 6.65s	remaining: 2m 39s
# 500:	learn: 7.8921263	test: 7.9577289	best: 7.9576135 (422)	total: 8.26s	remaining: 2m 36s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.957613498
# bestIteration = 422
#
# Shrink model to first 423 iterations.
# ===================== Fold 4 =====================
# 0:	learn: 7.9323037	test: 7.9701391	best: 7.9701391 (0)	total: 17.2ms	remaining: 2m 52s
# 100:	learn: 7.9178313	test: 7.9631693	best: 7.9631693 (100)	total: 1.66s	remaining: 2m 42s
# 200:	learn: 7.9105205	test: 7.9620358	best: 7.9620012 (197)	total: 3.31s	remaining: 2m 41s
# 300:	learn: 7.9043541	test: 7.9620288	best: 7.9619416 (214)	total: 4.94s	remaining: 2m 39s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.961941575
# bestIteration = 214
#
# Shrink model to first 215 iterations.
# ===================== Fold 5 =====================
# 0:	learn: 7.9353095	test: 7.9581301	best: 7.9581301 (0)	total: 16.4ms	remaining: 2m 44s
# 100:	learn: 7.9212386	test: 7.9500302	best: 7.9500302 (100)	total: 1.67s	remaining: 2m 43s
# 200:	learn: 7.9139822	test: 7.9488934	best: 7.9488934 (200)	total: 3.29s	remaining: 2m 40s
# 300:	learn: 7.9077182	test: 7.9485841	best: 7.9485506 (292)	total: 4.91s	remaining: 2m 38s
# 400:	learn: 7.9016806	test: 7.9484911	best: 7.9483034 (333)	total: 6.55s	remaining: 2m 36s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.94830344
# bestIteration = 333
#
# Shrink model to first 334 iterations.
# Mean valid score = 7.931072071796723 STD valid score =  0.0351026079472668
# Mean train score = 7.912449368705646 STD train score =  0.012081371318549049
# Drop Feature 6
# ===================== Fold 1 =====================
# 0:	learn: 7.9469668	test: 7.9114306	best: 7.9114306 (0)	total: 30.3ms	remaining: 5m 3s
# 100:	learn: 7.9324984	test: 7.9046304	best: 7.9046304 (100)	total: 2.03s	remaining: 3m 18s
# 200:	learn: 7.9253879	test: 7.9041830	best: 7.9041830 (200)	total: 3.68s	remaining: 2m 59s
# 300:	learn: 7.9189607	test: 7.9044918	best: 7.9041108 (212)	total: 5.33s	remaining: 2m 51s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.904110813
# bestIteration = 212
#
# Shrink model to first 213 iterations.
# ===================== Fold 2 =====================
# 0:	learn: 7.9517453	test: 7.8920218	best: 7.8920218 (0)	total: 16.1ms	remaining: 2m 41s
# 100:	learn: 7.9378117	test: 7.8846586	best: 7.8846586 (100)	total: 1.67s	remaining: 2m 43s
# 200:	learn: 7.9306197	test: 7.8837755	best: 7.8836618 (187)	total: 3.38s	remaining: 2m 45s
# 300:	learn: 7.9241327	test: 7.8836088	best: 7.8835845 (226)	total: 5.14s	remaining: 2m 45s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.883584477
# bestIteration = 226
#
# Shrink model to first 227 iterations.
# ===================== Fold 3 =====================
# 0:	learn: 7.9328993	test: 7.9676256	best: 7.9676256 (0)	total: 17.1ms	remaining: 2m 50s
# 100:	learn: 7.9193815	test: 7.9600606	best: 7.9600606 (100)	total: 1.65s	remaining: 2m 42s
# 200:	learn: 7.9119742	test: 7.9588803	best: 7.9588425 (190)	total: 3.31s	remaining: 2m 41s
# 300:	learn: 7.9055284	test: 7.9588439	best: 7.9586536 (265)	total: 4.97s	remaining: 2m 40s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.958653584
# bestIteration = 265
#
# Shrink model to first 266 iterations.
# ===================== Fold 4 =====================
# 0:	learn: 7.9323037	test: 7.9701391	best: 7.9701391 (0)	total: 16.2ms	remaining: 2m 42s
# 100:	learn: 7.9179046	test: 7.9635337	best: 7.9635337 (100)	total: 1.66s	remaining: 2m 42s
# 200:	learn: 7.9104928	test: 7.9629093	best: 7.9628552 (192)	total: 3.3s	remaining: 2m 41s
# 300:	learn: 7.9042509	test: 7.9627994	best: 7.9627749 (214)	total: 4.94s	remaining: 2m 39s
# 400:	learn: 7.8983049	test: 7.9630328	best: 7.9626686 (342)	total: 6.59s	remaining: 2m 37s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.962668561
# bestIteration = 342
#
# Shrink model to first 343 iterations.
# ===================== Fold 5 =====================
# 0:	learn: 7.9353095	test: 7.9581301	best: 7.9581301 (0)	total: 16.7ms	remaining: 2m 46s
# 100:	learn: 7.9213134	test: 7.9505012	best: 7.9505012 (100)	total: 1.67s	remaining: 2m 43s
# 200:	learn: 7.9142647	test: 7.9499712	best: 7.9498402 (192)	total: 3.31s	remaining: 2m 41s
# 300:	learn: 7.9081357	test: 7.9497512	best: 7.9497215 (298)	total: 4.93s	remaining: 2m 38s
# 400:	learn: 7.9018747	test: 7.9496604	best: 7.9496212 (398)	total: 6.6s	remaining: 2m 37s
# 500:	learn: 7.8949488	test: 7.9499475	best: 7.9495934 (425)	total: 8.2s	remaining: 2m 35s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.949593411
# bestIteration = 425
#
# Shrink model to first 426 iterations.
# Mean valid score = 7.931722169250241 STD valid score =  0.035644024432985165
# Mean train score = 7.912669795696006 STD train score =  0.013266541515885624
# Drop Feature 7
# ===================== Fold 1 =====================
# 0:	learn: 7.9469668	test: 7.9114306	best: 7.9114306 (0)	total: 16.3ms	remaining: 2m 42s
# 100:	learn: 7.9319399	test: 7.9042608	best: 7.9042608 (100)	total: 1.66s	remaining: 2m 43s
# 200:	learn: 7.9245706	test: 7.9034987	best: 7.9034987 (200)	total: 3.28s	remaining: 2m 39s
# 300:	learn: 7.9182220	test: 7.9031464	best: 7.9030559 (287)	total: 4.95s	remaining: 2m 39s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.90305595
# bestIteration = 287
#
# Shrink model to first 288 iterations.
# ===================== Fold 2 =====================
# 0:	learn: 7.9517453	test: 7.8920218	best: 7.8920218 (0)	total: 16.4ms	remaining: 2m 44s
# 100:	learn: 7.9373682	test: 7.8842861	best: 7.8842861 (100)	total: 1.73s	remaining: 2m 49s
# 200:	learn: 7.9302278	test: 7.8832852	best: 7.8832650 (195)	total: 3.4s	remaining: 2m 45s
# 300:	learn: 7.9237314	test: 7.8833235	best: 7.8831854 (261)	total: 5.05s	remaining: 2m 42s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.883185393
# bestIteration = 261
#
# Shrink model to first 262 iterations.
# ===================== Fold 3 =====================
# 0:	learn: 7.9328993	test: 7.9676256	best: 7.9676256 (0)	total: 17.1ms	remaining: 2m 50s
# 100:	learn: 7.9187188	test: 7.9593508	best: 7.9593508 (100)	total: 1.7s	remaining: 2m 46s
# 200:	learn: 7.9114699	test: 7.9576989	best: 7.9576989 (200)	total: 3.5s	remaining: 2m 50s
# 300:	learn: 7.9053933	test: 7.9575212	best: 7.9573795 (285)	total: 5.41s	remaining: 2m 54s
# 400:	learn: 7.8992619	test: 7.9576099	best: 7.9572920 (322)	total: 7.07s	remaining: 2m 49s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.957291986
# bestIteration = 322
#
# Shrink model to first 323 iterations.
# ===================== Fold 4 =====================
# 0:	learn: 7.9323037	test: 7.9701391	best: 7.9701391 (0)	total: 16ms	remaining: 2m 40s
# 100:	learn: 7.9175797	test: 7.9627883	best: 7.9627883 (100)	total: 1.67s	remaining: 2m 43s
# 200:	learn: 7.9100370	test: 7.9618853	best: 7.9618185 (194)	total: 3.31s	remaining: 2m 41s
# 300:	learn: 7.9035561	test: 7.9620179	best: 7.9617574 (230)	total: 4.97s	remaining: 2m 40s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.96175739
# bestIteration = 230
#
# Shrink model to first 231 iterations.
# ===================== Fold 5 =====================
# 0:	learn: 7.9353095	test: 7.9581301	best: 7.9581301 (0)	total: 17ms	remaining: 2m 49s
# 100:	learn: 7.9208921	test: 7.9500290	best: 7.9500290 (100)	total: 1.68s	remaining: 2m 44s
# 200:	learn: 7.9135277	test: 7.9491892	best: 7.9491432 (191)	total: 3.31s	remaining: 2m 41s
# 300:	learn: 7.9074910	test: 7.9492817	best: 7.9491233 (241)	total: 4.99s	remaining: 2m 40s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.949123256
# bestIteration = 241
#
# Shrink model to first 242 iterations.
# Mean valid score = 7.930882794941144 STD valid score =  0.03547102977896569
# Mean train score = 7.913699775509177 STD train score =  0.008870605760387798
# Improved Score = 7.930882794941144
# =================================================
# Drop Feature 8
# ===================== Fold 1 =====================
# 0:	learn: 7.9469969	test: 7.9113922	best: 7.9113922 (0)	total: 18.4ms	remaining: 3m 3s
# 100:	learn: 7.9340358	test: 7.9051375	best: 7.9051375 (100)	total: 1.74s	remaining: 2m 50s
# 200:	learn: 7.9280402	test: 7.9044680	best: 7.9043869 (190)	total: 3.41s	remaining: 2m 46s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.904386877
# bestIteration = 190
#
# Shrink model to first 191 iterations.
# ===================== Fold 2 =====================
# 0:	learn: 7.9517937	test: 7.8921696	best: 7.8921696 (0)	total: 17ms	remaining: 2m 49s
# 100:	learn: 7.9389983	test: 7.8864987	best: 7.8864874 (99)	total: 1.67s	remaining: 2m 43s
# 200:	learn: 7.9327279	test: 7.8861562	best: 7.8860773 (182)	total: 3.46s	remaining: 2m 48s
# 300:	learn: 7.9270667	test: 7.8864036	best: 7.8860382 (224)	total: 5.34s	remaining: 2m 52s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.886038156
# bestIteration = 224
#
# Shrink model to first 225 iterations.
# ===================== Fold 3 =====================
# 0:	learn: 7.9329309	test: 7.9676841	best: 7.9676841 (0)	total: 17.6ms	remaining: 2m 55s
# 100:	learn: 7.9206169	test: 7.9608440	best: 7.9608440 (100)	total: 1.67s	remaining: 2m 43s
# 200:	learn: 7.9143488	test: 7.9603655	best: 7.9603181 (189)	total: 3.35s	remaining: 2m 43s
# 300:	learn: 7.9087475	test: 7.9602702	best: 7.9601875 (293)	total: 5s	remaining: 2m 41s
# 400:	learn: 7.9033074	test: 7.9603729	best: 7.9601726 (328)	total: 6.66s	remaining: 2m 39s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.960172596
# bestIteration = 328
#
# Shrink model to first 329 iterations.
# ===================== Fold 4 =====================
# 0:	learn: 7.9323385	test: 7.9701959	best: 7.9701959 (0)	total: 16.5ms	remaining: 2m 45s
# 100:	learn: 7.9192733	test: 7.9642635	best: 7.9642462 (99)	total: 1.68s	remaining: 2m 44s
# 200:	learn: 7.9129626	test: 7.9636848	best: 7.9636257 (193)	total: 3.33s	remaining: 2m 42s
# 300:	learn: 7.9075922	test: 7.9637300	best: 7.9636100 (282)	total: 4.98s	remaining: 2m 40s
# 400:	learn: 7.9019472	test: 7.9635556	best: 7.9635078 (385)	total: 6.59s	remaining: 2m 37s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.9635078
# bestIteration = 385
#
# Shrink model to first 386 iterations.
# ===================== Fold 5 =====================
# 0:	learn: 7.9353170	test: 7.9580631	best: 7.9580631 (0)	total: 16.2ms	remaining: 2m 42s
# 100:	learn: 7.9229221	test: 7.9513785	best: 7.9513785 (100)	total: 1.71s	remaining: 2m 47s
# 200:	learn: 7.9165336	test: 7.9512769	best: 7.9512177 (156)	total: 3.34s	remaining: 2m 42s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.951217656
# bestIteration = 156
#
# Shrink model to first 157 iterations.
# Mean valid score = 7.93306461691177 STD valid score =  0.035443841244922114
# Mean train score = 7.917846901654466 STD train score =  0.012616172533495281
# Drop Feature 9
# ===================== Fold 1 =====================
# 0:	learn: 7.9469423	test: 7.9113449	best: 7.9113449 (0)	total: 17.5ms	remaining: 2m 54s
# 100:	learn: 7.9328437	test: 7.9048947	best: 7.9048947 (100)	total: 1.76s	remaining: 2m 52s
# 200:	learn: 7.9264058	test: 7.9042715	best: 7.9042715 (200)	total: 3.68s	remaining: 2m 59s
# 300:	learn: 7.9209007	test: 7.9040717	best: 7.9039959 (297)	total: 5.42s	remaining: 2m 54s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.903995939
# bestIteration = 297
#
# Shrink model to first 298 iterations.
# ===================== Fold 2 =====================
# 0:	learn: 7.9517534	test: 7.8920781	best: 7.8920781 (0)	total: 17.5ms	remaining: 2m 55s
# 100:	learn: 7.9379274	test: 7.8849674	best: 7.8849674 (100)	total: 1.69s	remaining: 2m 45s
# 200:	learn: 7.9313396	test: 7.8844598	best: 7.8844111 (199)	total: 3.35s	remaining: 2m 43s
# 300:	learn: 7.9254809	test: 7.8845379	best: 7.8843855 (240)	total: 4.98s	remaining: 2m 40s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.884385482
# bestIteration = 240
#
# Shrink model to first 241 iterations.
# ===================== Fold 3 =====================
# 0:	learn: 7.9328884	test: 7.9676582	best: 7.9676582 (0)	total: 17.3ms	remaining: 2m 52s
# 100:	learn: 7.9193280	test: 7.9598881	best: 7.9598881 (100)	total: 1.67s	remaining: 2m 43s
# 200:	learn: 7.9128451	test: 7.9591865	best: 7.9591614 (198)	total: 3.33s	remaining: 2m 42s
# 300:	learn: 7.9070753	test: 7.9592774	best: 7.9590962 (219)	total: 4.99s	remaining: 2m 40s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.959096248
# bestIteration = 219
#
# Shrink model to first 220 iterations.
# ===================== Fold 4 =====================
# 0:	learn: 7.9322911	test: 7.9701518	best: 7.9701518 (0)	total: 16.4ms	remaining: 2m 44s
# 100:	learn: 7.9184610	test: 7.9625818	best: 7.9625646 (99)	total: 1.67s	remaining: 2m 43s
# 200:	learn: 7.9119339	test: 7.9615421	best: 7.9614925 (195)	total: 3.37s	remaining: 2m 44s
# 300:	learn: 7.9063428	test: 7.9614622	best: 7.9612838 (252)	total: 5.05s	remaining: 2m 42s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.961283762
# bestIteration = 252
#
# Shrink model to first 253 iterations.
# ===================== Fold 5 =====================
# 0:	learn: 7.9352928	test: 7.9580413	best: 7.9580413 (0)	total: 17.1ms	remaining: 2m 50s
# 100:	learn: 7.9218273	test: 7.9499363	best: 7.9499363 (100)	total: 1.72s	remaining: 2m 48s
# 200:	learn: 7.9153852	test: 7.9489765	best: 7.9489506 (198)	total: 3.42s	remaining: 2m 46s
# 300:	learn: 7.9099686	test: 7.9488775	best: 7.9487314 (254)	total: 5.34s	remaining: 2m 52s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 7.948731423
# bestIteration = 254
#
# Shrink model to first 255 iterations.
# Mean valid score = 7.93149857067178 STD valid score =  0.03507776562118874
# Mean train score = 7.916565936250498 STD train score =  0.008272272500577679
# Good scores : [7.931280332811913, 7.931054290827151, 7.930916343242673, 7.930882794941144]
# Harmful features : [0, 1, 7]

# %%
# let's see the reduction in X and test sets after performing LOFO
print("X shape after transformation :", X.shape)
print("test shape after transformation :", test.shape)
# Out:
# X shape after transformation : (250000, 7)
# test shape after transformation : (150000, 7)
